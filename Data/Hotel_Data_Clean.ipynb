# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('HotelsManhOrl.csv')
df
# Out:
#           city                                         hotel_name acc_type  \
# 0      Orlando  Sonesta ES Suites Orlando - International Driv...    HOTEL
# 1      Orlando   CoCo Key Hotel and Water Resort-Orlando, Orlando    HOTEL
# 2      Orlando  The Grand Orlando Resort at Celebration, Kissi...    HOTEL
# 3      Orlando  Holiday Inn & Suites Across From Universal Orl...    HOTEL
# 4      Orlando  Howard Johnson by Wyndham Tropical Palms Kissi...    HOTEL
# 5      Orlando            Baymont by Wyndham Kissimmee, Kissimmee    HOTEL
# 6      Orlando  Holiday Inn Orlando International Airport, Orl...    HOTEL
# 7      Orlando  Clarion Inn Lake Buena Vista, a Rosen Hotel, O...    HOTEL
# 8      Orlando  Days Inn & Suites by Wyndham Altamonte Springs...    HOTEL
# 9      Orlando  Delta Hotels by Marriott Orlando Lake Buena Vi...    HOTEL
# 10     Orlando  Hyatt Regency Orlando International Airport, O...    HOTEL
# ...

# %%
hotel=df.lat_long.astype(str).str.replace('\[|\]|\'','')
Hotel=hotel.to_frame()
Hotel
# Out:
#                   lat_long
# 0     28.441941, -81.47115
# 1     28.45468, -81.470854
# 2     28.33647, -81.534655
# 3    28.477329, -81.457288
# 4    28.304833, -81.455483
# 5     28.303313, -81.44829
# 6     28.46027, -81.309057
# 7    28.387403, -81.499148
# 8    28.660884, -81.393403
# 9     28.38414, -81.505944
# 10   28.431373, -81.305213
# 11   28.332726, -81.511951
# 12   28.568406, -81.264167
# 13   28.362681, -81.501165
# 14    28.460379, -81.31317
# 15   28.405897, -81.528661
# 16   28.650083, -81.350144
# 17    28.439032, -81.47157
# 18    28.28522, -81.352644
# 19   28.357377, -81.494643
# 20    28.458296, -81.47017
# 21   28.328156, -81.590693
# 22   28.462304, -81.461441
# 23   28.329881, -81.489634
# 24   28.459671, -81.312231
# 25   28.385062, -81.536421
# 26   28.547271, -81.384604
# 27   28.477995, -81.457445
# 28   28.489394, -81.405168
# 29     28.33465, -81.48153
# ..                     ...
# 854  40.774295, -73.952649
# 855     40.7609, -73.98893
# ...

# %%
#import geopyp to translate lat_long to zipcode
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="specify_your_app_name_here", timeout=100000)

p=[]
for i in Hotel['lat_long']:
    try:
        p.append((((geolocator.reverse(i)).raw)['address'])['postcode'])
    except:
        p.append('no')

# %%
#append zipcode to dataframe
df['zipcode']=p

# %%
hotel_new = df.loc[df['city'] == 'Manhattan']
hotel_new

# %%
#export_csv = hotel_new.to_csv ('hotel_new.csv', index = None, header=True)

# %%
df = df[['hotel_name','zipcode','lat_long']]

# %%
df=df.loc[df['zipcode']!='no']

# %%
df['zipcode'] = df['zipcode'].str[:5]
df['zipcode'] = df['zipcode'].astype(int)

# %%
df=df.rename(columns={'zipcode': 'zip'})

# %%
MT=[10026, 10027, 10030, 10037, 10039, 10001, 
    10011, 10018, 10019, 10020, 10036, 10029, 
    10035, 10010, 10016, 10017, 10022, 10012, 
    10013, 10014, 10004, 10005, 10006, 10007, 
    10038, 10280, 10002, 10003, 10009, 10021, 
    10028, 10044, 10065, 10075, 10128, 10023, 
    10024, 10025, 10031, 10032, 10033, 10034, 
    10040]
#source = https://www.health.ny.gov/statistics/cancer/registry/appendix/neighborhoods.htm

# %%
df=df[df['zip'].isin(MT)]

# %%
#export_csv = df.to_csv ('hotel.csv', index = None, header=True)
